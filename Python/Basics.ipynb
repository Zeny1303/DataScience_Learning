# %% [markdown]
# # Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
user_input = input("Enter the input you like to print it ")
print(f"Here is your input -- {user_input}")
# Out:
# Here is your input -- Hii, my name is Sneha

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
Number = int(input("Enter your desired Number to check it is positive, negative, or zero"))
if Number > 0:
    print("Positive Number ")
elif Number <0 :
    print("Negative Number")
else:
    print("OHH, That'S ZEROOOOOo")
# Out:
# OHH, That'S ZEROOOOOo

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
a=int(input("Enter a first Number"))
b=int(input("Enter a second Number"))
c=int(input("Enter a third Number"))

if a > b and a > c:
    print(f"First Number, {a} is largest among all ")
elif b> a and b > c:
    print(f"Second Number, {b} is largest among all ")
else:
    print(f"Third Number, {c} is largest among all ")
# Out:
# Second Number, 56 is largest among all

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here

#factorial -> n*n-1*n-2 till n- something = 1
def factorial(Number):
    if Number == 0 or Number == 1:
        return 1 
    else:
        return Number * factorial(Number-1)
    
Number = int(input("Enter a number "))
print(f"The Number is {Number}")
result = factorial(Number)
print (f"The factorial of {Number} is {result}")
# Out:
# The Number is 8
# The factorial of a 8 is 40320

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
A=34
B=23.34
C="HIIIIIII"
D=True
print("Data type of A,", A, "is", type(A))
print("Data type of B,", B, "is", type(B))
print("Data type of C,", C, "is", type(C))
print("Data type of D,", D, "is", type(D))
# Out:
# Data type of A, 34 is <class 'int'>
# Data type of B, 23.34 is <class 'float'>
# Data type of C, HIIIIIII is <class 'str'>
# Data type of D, True is <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a = 2
b= 3
print("a before swap:-",a)
print("b before swap:-",b)
c= a
a=b
b=c
print("a after swap:-",a)
print("b after swap:-",b)
# Out:
# a before swap:- 2
# b before swap:- 3
# a after swap:- 3
# b after swap:- 2

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
Celsius = float(input("Enter temperature"))
Fahrenheit = (Celsius * 9/5)+32
print(Fahrenheit)
# Out:
# 132.8

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = "Happy"
str2 = "Birthday"
concate_2_strings = (str1)+(str2)
print(f"wish u very {concate_2_strings}")
# Out:
# wish u very HappyBirthday

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
